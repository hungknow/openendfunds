# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys; sys.path.insert(0, '..')
from baoviet.baocaohoatdongdautu import read_BaoCaoHoatDongDauTu
import datetime

# %%
read_BaoCaoHoatDongDauTu("data/1691166680_baocaohoatdongdautu_thang_07.2023_bvbf.xlsx")
# Out:
# 2023-07-01
#                                                     0        1  \
# 0              BÁO CÁO VỀ HOẠT ĐỘNG ĐẦU TƯ CỦA QUỸ MỞ      NaN
# 1                                                 NaN      NaN
# 2
# 3
# 4
# 5
# 6   1. Tên Công ty quản lý quỹ: Công ty TNHH Quản ...      NaN
# 7   2. Tên Ngân hàng giám sát: Ngân hàng TMCP Đầu ...      NaN
# 8          3. Tên Quỹ: Quỹ đầu tư Trái phiếu Bảo Việt      NaN
# 9                     4. Ngày lập báo cáo: 02/08/2023      NaN
# 10
# 11
# 12                                                         STT
# 13                                                           1
# 14                                                           2
# 15                                                           3
# 16                                                           4
# 17                                                           5
# 18                                                NaN        6
# ...
